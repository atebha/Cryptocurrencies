# %% [markdown]
# # Clustering Crypto

# %%
# !pip install hvplot
# !pip install scikit-learn
# !pip install plotly
# !pip install path
# Out:
# Requirement already satisfied: hvplot in c:\users\tebha.ahsan\anaconda3\lib\site-packages (0.7.1)
# Requirement already satisfied: pandas in c:\users\tebha.ahsan\anaconda3\lib\site-packages (from hvplot) (1.1.3)
# Requirement already satisfied: numpy>=1.15 in c:\users\tebha.ahsan\anaconda3\lib\site-packages (from hvplot) (1.19.2)
# Requirement already satisfied: colorcet>=2 in c:\users\tebha.ahsan\anaconda3\lib\site-packages (from hvplot) (2.0.6)
# Requirement already satisfied: bokeh>=1.0.0 in c:\users\tebha.ahsan\anaconda3\lib\site-packages (from hvplot) (2.2.3)
# Requirement already satisfied: holoviews>=1.11.0 in c:\users\tebha.ahsan\anaconda3\lib\site-packages (from hvplot) (1.14.3)
# Requirement already satisfied: pytz>=2017.2 in c:\users\tebha.ahsan\anaconda3\lib\site-packages (from pandas->hvplot) (2020.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\tebha.ahsan\anaconda3\lib\site-packages (from pandas->hvplot) (2.8.1)
# Requirement already satisfied: param>=1.7.0 in c:\users\tebha.ahsan\anaconda3\lib\site-packages (from colorcet>=2->hvplot) (1.10.1)
# Requirement already satisfied: pyct>=0.4.4 in c:\users\tebha.ahsan\anaconda3\lib\site-packages (from colorcet>=2->hvplot) (0.4.8)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\tebha.ahsan\anaconda3\lib\site-packages (from bokeh>=1.0.0->hvplot) (8.0.1)
# Requirement already satisfied: packaging>=16.8 in c:\users\tebha.ahsan\anaconda3\lib\site-packages (from bokeh>=1.0.0->hvplot) (20.4)
# Requirement already satisfied: tornado>=5.1 in c:\users\tebha.ahsan\anaconda3\lib\site-packages (from bokeh>=1.0.0->hvplot) (6.0.4)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\tebha.ahsan\anaconda3\lib\site-packages (from bokeh>=1.0.0->hvplot) (5.3.1)
# Requirement already satisfied: Jinja2>=2.7 in c:\users\tebha.ahsan\anaconda3\lib\site-packages (from bokeh>=1.0.0->hvplot) (2.11.2)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\users\tebha.ahsan\anaconda3\lib\site-packages (from bokeh>=1.0.0->hvplot) (3.7.4.3)
# Requirement already satisfied: panel>=0.8.0 in c:\users\tebha.ahsan\anaconda3\lib\site-packages (from holoviews>=1.11.0->hvplot) (0.11.3)
# Requirement already satisfied: pyviz-comms>=0.7.4 in c:\users\tebha.ahsan\anaconda3\lib\site-packages (from holoviews>=1.11.0->hvplot) (2.0.1)
# Requirement already satisfied: six>=1.5 in c:\users\tebha.ahsan\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->hvplot) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\tebha.ahsan\anaconda3\lib\site-packages (from packaging>=16.8->bokeh>=1.0.0->hvplot) (2.4.7)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\tebha.ahsan\anaconda3\lib\site-packages (from Jinja2>=2.7->bokeh>=1.0.0->hvplot) (1.1.1)
# Requirement already satisfied: tqdm in c:\users\tebha.ahsan\anaconda3\lib\site-packages (from panel>=0.8.0->holoviews>=1.11.0->hvplot) (4.50.2)
# Requirement already satisfied: requests in c:\users\tebha.ahsan\anaconda3\lib\site-packages (from panel>=0.8.0->holoviews>=1.11.0->hvplot) (2.24.0)
# Requirement already satisfied: markdown in c:\users\tebha.ahsan\anaconda3\lib\site-packages (from panel>=0.8.0->holoviews>=1.11.0->hvplot) (3.3.4)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\tebha.ahsan\anaconda3\lib\site-packages (from requests->panel>=0.8.0->holoviews>=1.11.0->hvplot) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\tebha.ahsan\anaconda3\lib\site-packages (from requests->panel>=0.8.0->holoviews>=1.11.0->hvplot) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\tebha.ahsan\anaconda3\lib\site-packages (from requests->panel>=0.8.0->holoviews>=1.11.0->hvplot) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tebha.ahsan\anaconda3\lib\site-packages (from requests->panel>=0.8.0->holoviews>=1.11.0->hvplot) (2020.6.20)
# Requirement already satisfied: scikit-learn in c:\users\tebha.ahsan\anaconda3\lib\site-packages (0.23.1)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\tebha.ahsan\anaconda3\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\tebha.ahsan\anaconda3\lib\site-packages (from scikit-learn) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\tebha.ahsan\anaconda3\lib\site-packages (from scikit-learn) (0.17.0)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\tebha.ahsan\anaconda3\lib\site-packages (from scikit-learn) (1.19.2)
# Requirement already satisfied: plotly in c:\users\tebha.ahsan\anaconda3\lib\site-packages (4.14.3)
# Requirement already satisfied: six in c:\users\tebha.ahsan\anaconda3\lib\site-packages (from plotly) (1.15.0)
# Requirement already satisfied: retrying>=1.3.3 in c:\users\tebha.ahsan\anaconda3\lib\site-packages (from plotly) (1.3.3)
# Requirement already satisfied: path in c:\users\tebha.ahsan\anaconda3\lib\site-packages (15.0.0)

# %%
# Initial imports
import pandas as pd
import hvplot.pandas
from path import Path
import plotly.express as px
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-6-1083e8ce8e0d> in <module>
#       1 # Initial imports
#       2 import pandas as pd
# ----> 3 import hvplot.pandas
#       4 from path import Path
#       5 import plotly.express as px
#
# ~\Anaconda3\lib\site-packages\hvplot\__init__.py in <module>
#       6
#       7 import param
# ----> 8 import holoviews as _hv
#       9
#      10 from holoviews import Store
#
# ~\Anaconda3\lib\site-packages\holoviews\__init__.py in <module>
#      10
#      11 from . import util                                       # noqa (API import)
# ---> 12 from .annotators import annotate                         # noqa (API import)
#      13 from .core import archive, config                        # noqa (API import)
#      14 from .core.boundingregion import BoundingBox             # noqa (API import)
#
# ~\Anaconda3\lib\site-packages\holoviews\annotators.py in <module>
#       8 import param
#       9
# ---> 10 from panel.pane import PaneBase
#      11 from panel.layout import Row, Tabs
#      12 from panel.util import param_name
#
# ~\Anaconda3\lib\site-packages\panel\__init__.py in <module>
# ----> 1 from . import layout # noqa
#       2 from . import links # noqa
#       3 from . import pane # noqa
#       4 from . import param # noqa
#       5 from . import pipeline # noqa
#
# ~\Anaconda3\lib\site-packages\panel\layout\__init__.py in <module>
# ----> 1 from .accordion import Accordion # noqa
#       2 from .base import Column, ListLike, ListPanel, Panel, Row, WidgetBox # noqa
#       3 from .card import Card # noqa
#       4 from .grid import GridBox, GridSpec # noqa
#       5 from .spacer import Divider, HSpacer, Spacer, VSpacer # noqa
#
# ~\Anaconda3\lib\site-packages\panel\layout\accordion.py in <module>
#       4
#       5 from .base import NamedListPanel
# ----> 6 from .card import Card
#       7
#       8
#
# ~\Anaconda3\lib\site-packages\panel\layout\card.py in <module>
#       1 import param
#       2
# ----> 3 from ..models import Card as BkCard
#       4 from .base import Column, Row, ListPanel
#       5
#
# ~\Anaconda3\lib\site-packages\panel\models\__init__.py in <module>
#       6 """
#       7
# ----> 8 from .datetime_picker import DatetimePicker  # noqa
#       9 from .idom import IDOM # noqa
#      10 from .ipywidget import IPyWidget # noqa
#
# ~\Anaconda3\lib\site-packages\panel\models\datetime_picker.py in <module>
#       1 from bokeh.core.enums import CalendarPosition
# ----> 2 from bokeh.core.properties import (
#       3     Bool,
#       4     Date,
#       5     Datetime,
#
# ImportError: cannot import name 'Nullable' from 'bokeh.core.properties' (C:\Users\tebha.ahsan\Anaconda3\lib\site-packages\bokeh\core\properties.py)

# %% [markdown]
# ### Deliverable 1: Preprocessing the Data for PCA

# %%
# Load the crypto_data.csv dataset.
file_path = "crypto_data.csv"
crypto_df = pd.read_csv(file_path, index_col = 0)
crypto_df.head(5)
# Out:
#       CoinName Algorithm  IsTrading ProofType  TotalCoinsMined TotalCoinSupply
# 42     42 Coin    Scrypt       True   PoW/PoS     4.199995e+01              42
# 365    365Coin       X11       True   PoW/PoS              NaN      2300000000
# 404    404Coin    Scrypt       True   PoW/PoS     1.055185e+09       532000000
# 611  SixEleven   SHA-256       True       PoW              NaN          611000
# 808        808   SHA-256       True   PoW/PoS     0.000000e+00               0

# %%
# Keep all the cryptocurrencies that are being traded.
crypto_df = crypto_df[crypto_df.IsTrading == True]
crypto_df.head()
# Out:
#       CoinName Algorithm  IsTrading ProofType  TotalCoinsMined TotalCoinSupply
# 42     42 Coin    Scrypt       True   PoW/PoS     4.199995e+01              42
# 365    365Coin       X11       True   PoW/PoS              NaN      2300000000
# 404    404Coin    Scrypt       True   PoW/PoS     1.055185e+09       532000000
# 611  SixEleven   SHA-256       True       PoW              NaN          611000
# 808        808   SHA-256       True   PoW/PoS     0.000000e+00               0

# %%
# Keep all the cryptocurrencies that have a working algorithm.
crypto_df["Algorithm"].isnull().sum()
# Out:
# 0

# %%
# Remove the "IsTrading" column. 
crypto_df.drop(columns="IsTrading", axis=1, inplace=True)
crypto_df
# Out:
#          CoinName    Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 42        42 Coin       Scrypt   PoW/PoS     4.199995e+01              42
# 365       365Coin          X11   PoW/PoS              NaN      2300000000
# 404       404Coin       Scrypt   PoW/PoS     1.055185e+09       532000000
# 611     SixEleven      SHA-256       PoW              NaN          611000
# 808           808      SHA-256   PoW/PoS     0.000000e+00               0
# ...           ...          ...       ...              ...             ...
# SERO   Super Zero       Ethash       PoW              NaN      1000000000
# UOS           UOS      SHA-256      DPoI              NaN      1000000000
# BDX        Beldex  CryptoNight       PoW     9.802226e+08      1400222610
# ZEN       Horizen     Equihash       PoW     7.296538e+06        21000000
# XBC   BitcoinPlus       Scrypt       PoS     1.283270e+05         1000000
#
# [1144 rows x 5 columns]

# %%
# Remove rows that have at least 1 null value.
crypto_df=crypto_df.dropna()
crypto_df
# Out:
#          CoinName    Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 42        42 Coin       Scrypt   PoW/PoS     4.199995e+01              42
# 404       404Coin       Scrypt   PoW/PoS     1.055185e+09       532000000
# 808           808      SHA-256   PoW/PoS     0.000000e+00               0
# 1337    EliteCoin          X13   PoW/PoS     2.927942e+10    314159265359
# BTC       Bitcoin      SHA-256       PoW     1.792718e+07        21000000
# ...           ...          ...       ...              ...             ...
# ZEPH       ZEPHYR      SHA-256      DPoS     2.000000e+09      2000000000
# GAP       Gapcoin       Scrypt   PoW/PoS     1.493105e+07       250000000
# BDX        Beldex  CryptoNight       PoW     9.802226e+08      1400222610
# ZEN       Horizen     Equihash       PoW     7.296538e+06        21000000
# XBC   BitcoinPlus       Scrypt       PoS     1.283270e+05         1000000
#
# [685 rows x 5 columns]

# %%
# Keep the rows where coins are mined.
crypto_df = crypto_df[crypto_df.TotalCoinsMined > 0]
crypto_df
# Out:
#          CoinName    Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 42        42 Coin       Scrypt   PoW/PoS     4.199995e+01              42
# 404       404Coin       Scrypt   PoW/PoS     1.055185e+09       532000000
# 1337    EliteCoin          X13   PoW/PoS     2.927942e+10    314159265359
# BTC       Bitcoin      SHA-256       PoW     1.792718e+07        21000000
# ETH      Ethereum       Ethash       PoW     1.076842e+08               0
# ...           ...          ...       ...              ...             ...
# ZEPH       ZEPHYR      SHA-256      DPoS     2.000000e+09      2000000000
# GAP       Gapcoin       Scrypt   PoW/PoS     1.493105e+07       250000000
# BDX        Beldex  CryptoNight       PoW     9.802226e+08      1400222610
# ZEN       Horizen     Equihash       PoW     7.296538e+06        21000000
# XBC   BitcoinPlus       Scrypt       PoS     1.283270e+05         1000000
#
# [532 rows x 5 columns]

# %%
# Create a new DataFrame that holds only the cryptocurrencies names.
crypto_name_df = pd.DataFrame(crypto_df["CoinName"], index=crypto_df.index)
crypto_name_df
# Out:
#          CoinName
# 42        42 Coin
# 404       404Coin
# 1337    EliteCoin
# BTC       Bitcoin
# ETH      Ethereum
# ...           ...
# ZEPH       ZEPHYR
# GAP       Gapcoin
# BDX        Beldex
# ZEN       Horizen
# XBC   BitcoinPlus
#
# [532 rows x 1 columns]

# %%
# Drop the 'CoinName' column since it's not going to be used on the clustering algorithm.
crypto_df.drop("CoinName", axis = 1, inplace=True)
crypto_df
# Out:
# C:\Users\tebha.ahsan\Anaconda3\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#         Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 42         Scrypt   PoW/PoS     4.199995e+01              42
# 404        Scrypt   PoW/PoS     1.055185e+09       532000000
# 1337          X13   PoW/PoS     2.927942e+10    314159265359
# BTC       SHA-256       PoW     1.792718e+07        21000000
# ETH        Ethash       PoW     1.076842e+08               0
# ...           ...       ...              ...             ...
# ZEPH      SHA-256      DPoS     2.000000e+09      2000000000
# GAP        Scrypt   PoW/PoS     1.493105e+07       250000000
# BDX   CryptoNight       PoW     9.802226e+08      1400222610
# ZEN      Equihash       PoW     7.296538e+06        21000000
# XBC        Scrypt       PoS     1.283270e+05         1000000
#
# [532 rows x 4 columns]

# %%
# Use get_dummies() to create variables for text features.
X = pd.get_dummies(data=crypto_df, columns=["Algorithm", "ProofType"])
X
# Out:
#       TotalCoinsMined TotalCoinSupply  Algorithm_1GB AES Pattern Search  \
# 42       4.199995e+01              42                                 0
# 404      1.055185e+09       532000000                                 0
# 1337     2.927942e+10    314159265359                                 0
# BTC      1.792718e+07        21000000                                 0
# ETH      1.076842e+08               0                                 0
# ...               ...             ...                               ...
# ZEPH     2.000000e+09      2000000000                                 0
# GAP      1.493105e+07       250000000                                 0
# BDX      9.802226e+08      1400222610                                 0
# ZEN      7.296538e+06        21000000                                 0
# XBC      1.283270e+05         1000000                                 0
#
#       Algorithm_536  Algorithm_Argon2d  Algorithm_BLAKE256  Algorithm_Blake  \
# 42                0                  0                   0                0
# 404               0                  0                   0                0
# 1337              0                  0                   0                0
# BTC               0                  0                   0                0
# ETH               0                  0                   0                0
# ...             ...                ...                 ...              ...
# ZEPH              0                  0                   0                0
# GAP               0                  0                   0                0
# BDX               0                  0                   0                0
# ZEN               0                  0                   0                0
# XBC               0                  0                   0                0
#
#       Algorithm_Blake2S  Algorithm_Blake2b  Algorithm_C11  ...  \
# 42                    0                  0              0  ...
# 404                   0                  0              0  ...
# 1337                  0                  0              0  ...
# BTC                   0                  0              0  ...
# ETH                   0                  0              0  ...
# ...                 ...                ...            ...  ...
# ZEPH                  0                  0              0  ...
# GAP                   0                  0              0  ...
# BDX                   0                  0              0  ...
# ZEN                   0                  0              0  ...
# XBC                   0                  0              0  ...
#
#       ProofType_PoW/PoS  ProofType_PoW/PoS   ProofType_PoW/PoW  \
# 42                    1                   0                  0
# 404                   1                   0                  0
# 1337                  1                   0                  0
# BTC                   0                   0                  0
# ETH                   0                   0                  0
# ...                 ...                 ...                ...
# ZEPH                  0                   0                  0
# GAP                   1                   0                  0
# BDX                   0                   0                  0
# ZEN                   0                   0                  0
# XBC                   0                   0                  0
#
#       ProofType_PoW/nPoS  ProofType_Pos  ProofType_Proof of Authority  \
# 42                     0              0                             0
# 404                    0              0                             0
# 1337                   0              0                             0
# BTC                    0              0                             0
# ETH                    0              0                             0
# ...                  ...            ...                           ...
# ZEPH                   0              0                             0
# GAP                    0              0                             0
# BDX                    0              0                             0
# ZEN                    0              0                             0
# XBC                    0              0                             0
#
#       ProofType_Proof of Trust  ProofType_TPoS  \
# 42                           0               0
# 404                          0               0
# 1337                         0               0
# BTC                          0               0
# ETH                          0               0
# ...                        ...             ...
# ZEPH                         0               0
# GAP                          0               0
# BDX                          0               0
# ZEN                          0               0
# XBC                          0               0
#
#       ProofType_Zero-Knowledge Proof  ProofType_dPoW/PoW
# 42                                 0                   0
# 404                                0                   0
# 1337                               0                   0
# BTC                                0                   0
# ETH                                0                   0
# ...                              ...                 ...
# ZEPH                               0                   0
# GAP                                0                   0
# BDX                                0                   0
# ZEN                                0                   0
# XBC                                0                   0
#
# [532 rows x 98 columns]

# %%
# Standardize the data with StandardScaler().
X_scaled = StandardScaler().fit_transform(X)
print(X_scaled[0:5])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-94908b1208f6> in <module>
#       1 # Standardize the data with StandardScaler().
# ----> 2 X_scaled = StandardScaler().fit_transform(X)
#       3 print(X_scaled[0:5])
#
# NameError: name 'StandardScaler' is not defined

# %% [markdown]
# ### Deliverable 2: Reducing Data Dimensions Using PCA

# %%
# Using PCA to reduce dimension to three principal components.
pca = PCA(n_components=3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-a1741c78204e> in <module>
#       1 # Using PCA to reduce dimension to three principal components.
# ----> 2 pca = PCA(n_components=3)
#
# NameError: name 'PCA' is not defined

# %%
# Create a DataFrame with the three principal components.
X_pca = pca.fit_transform(X_scaled)

pcs_df =pd.DataFrame(
    data=X_pca, columns=["PC 1", "PC 2", "PC 3"], index = crypto_df.index
)
pcs_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-9a7bf00838e9> in <module>
#       1 # Create a DataFrame with the three principal components.
# ----> 2 X_pca = pca.fit_transform(X_scaled)
#       3
#       4 pcs_df =pd.DataFrame(
#       5     data=X_pca, columns=["PC 1", "PC 2", "PC 3"], index = crypto_df.index
#
# NameError: name 'pca' is not defined

# %% [markdown]
# ### Deliverable 3: Clustering Crytocurrencies Using K-Means
#
# #### Finding the Best Value for `k` Using the Elbow Curve

# %%
# Create an elbow curve to find the best value for K.

inertia = []
k = list(range(1, 11))

# Calculate the inertia for the range of K values
for i in k:
    km = KMeans(n_clusters=i, random_state=0)
    km.fit(pcs_df)
    inertia.append(km.inertia_)

# Create the elbow curve
elbow_data = {"k": k, "inertia": inertia}
df_elbow = pd.DataFrame(elbow_data)
df_elbow.hvplot.line(x="k", y="inertia", xticks=k, title="Elbow Curve")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-614454359220> in <module>
#       6 # Calculate the inertia for the range of K values
#       7 for i in k:
# ----> 8     km = KMeans(n_clusters=i, random_state=0)
#       9     km.fit(pcs_df)
#      10     inertia.append(km.inertia_)
#
# NameError: name 'KMeans' is not defined

# %% [markdown]
# Running K-Means with `k=4`

# %%
# Initialize the K-Means model.
model = KMeans(n_clusters=4, random_state=0)

# Fit the model
model.fit(pcs_df)

# Predict clusters
predictions = model.predict(pcs_df)
print(predictions)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-eaf18b079f25> in <module>
#       1 # Initialize the K-Means model.
# ----> 2 model = KMeans(n_clusters=4, random_state=0)
#       3
#       4 # Fit the model
#       5 model.fit(pcs_df)
#
# NameError: name 'KMeans' is not defined

# %%
# Create a new DataFrame including predicted clusters and cryptocurrencies features.
# Concatentate the crypto_df and pcs_df DataFrames on the same columns.
clustered_df = pd.concat([new_crypto_df, pcs_df], axis = 1, sort = False)

#  Add a new column, "CoinName" to the clustered_df DataFrame that holds the names of the cryptocurrencies. 
clustered_df["CoinName"] = crypto_name_df["CoinName"]

#  Add a new column, "Class" to the clustered_df DataFrame that holds the predictions.
clustered_df['Class'] = model.labels_

# Print the shape of the clustered_df
print(clustered_df.shape)
clustered_df.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-0328046b7ec7> in <module>
#       1 # Create a new DataFrame including predicted clusters and cryptocurrencies features.
#       2 # Concatentate the crypto_df and pcs_df DataFrames on the same columns.
# ----> 3 clustered_df = pd.concat([new_crypto_df, pcs_df], axis = 1, sort = False)
#       4
#       5 #  Add a new column, "CoinName" to the clustered_df DataFrame that holds the names of the cryptocurrencies.
#
# NameError: name 'new_crypto_df' is not defined

# %% [markdown]
# ### Deliverable 4: Visualizing Cryptocurrencies Results
#
# #### 3D-Scatter with Clusters

# %%
# Creating a 3D-Scatter with the PCA data and the clusters
fig = px.scatter_3d(
    clustered_df,
    x="PC 1",
    y="PC 2",
    z="PC 3",
    color="Class",
    symbol="Class",
    hover_name = "CoinName",
    hover_data = ["Algorithm"],
    width=800,
)
fig.update_layout(legend=dict(x=0, y=1))
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-c2336829e423> in <module>
#       1 # Creating a 3D-Scatter with the PCA data and the clusters
# ----> 2 fig = px.scatter_3d(
#       3     clustered_df,
#       4     x="PC 1",
#       5     y="PC 2",
#
# NameError: name 'px' is not defined

# %%
# Create a table with tradable cryptocurrencies.
clustered_df.hvplot.table(columns=['CoinName', 'Algorithm', 'ProofType', 'TotalCoinSupply', 'TotalCoinsMined', 'Class'],
                          sortable=True, selectable=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-39a6cb080d25> in <module>
#       1 # Create a table with tradable cryptocurrencies.
# ----> 2 clustered_df.hvplot.table(columns=['CoinName', 'Algorithm', 'ProofType', 'TotalCoinSupply', 'TotalCoinsMined', 'Class'],
#       3                           sortable=True, selectable=True)
#
# NameError: name 'clustered_df' is not defined

# %%
# Print the total number of tradable cryptocurrencies.
print(f'We have {clustered_df["CoinName"].count()} tradable coins.')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-33f0270a17e4> in <module>
#       1 # Print the total number of tradable cryptocurrencies.
# ----> 2 print(f'We have {clustered_df["CoinName"].count()} tradable coins.')
#
# NameError: name 'clustered_df' is not defined

# %%
# Scaling data to create the scatter plot with tradable cryptocurrencies.
scaled_crypto=MinMaxScaler().fit_transform(clustered_df[['TotalCoinSupply', 'TotalCoinsMined']])
scaled_crypto
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-1abae54bc06c> in <module>
#       1 # Scaling data to create the scatter plot with tradable cryptocurrencies.
# ----> 2 scaled_crypto=MinMaxScaler().fit_transform(clustered_df[['TotalCoinSupply', 'TotalCoinsMined']])
#       3 scaled_crypto
#
# NameError: name 'MinMaxScaler' is not defined

# %%
# Create a new DataFrame that has the scaled data with the clustered_df DataFrame index.
plot_df = pd.DataFrame(data=scaled_crypto, columns=['TotalCoinSupply', 'TotalCoinsMined'], index=clustered_df.index)

# Add the "CoinName" column from the clustered_df DataFrame to the new DataFrame.
plot_df["CoinName"] = clustered_df["CoinName"]

# Add the "Class" column from the clustered_df DataFrame to the new DataFrame. 
plot_df["Class"] = clustered_df["Class"]

plot_df.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-36d8bcb8d0bc> in <module>
#       1 # Create a new DataFrame that has the scaled data with the clustered_df DataFrame index.
# ----> 2 plot_df = pd.DataFrame(data=scaled_crypto, columns=['TotalCoinSupply', 'TotalCoinsMined'], index=clustered_df.index)
#       3
#       4 # Add the "CoinName" column from the clustered_df DataFrame to the new DataFrame.
#       5 plot_df["CoinName"] = clustered_df["CoinName"]
#
# NameError: name 'scaled_crypto' is not defined

# %%
# Create a hvplot.scatter plot using x="TotalCoinsMined" and y="TotalCoinSupply".
# Creating a 3D-Scatter with the PCA data and the clusters
plot_df.hvplot.scatter(
    x="TotalCoinsMined",
    y="TotalCoinSupply",
    hover_cols=["CoinName"],
    by="Class",
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-ada962f68655> in <module>
#       1 # Create a hvplot.scatter plot using x="TotalCoinsMined" and y="TotalCoinSupply".
#       2 # Creating a 3D-Scatter with the PCA data and the clusters
# ----> 3 plot_df.hvplot.scatter(
#       4     x="TotalCoinsMined",
#       5     y="TotalCoinSupply",
#
# NameError: name 'plot_df' is not defined
